# %% [markdown]
# <a href="https://colab.research.google.com/github/ReidelVichot/PUS2022_Heat-TreesPHL/blob/main/MidTermExploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.1 MB 28.1 MB/s
# ...
#      |████████████████████████████████| 16.6 MB 72.8 MB/s
# ...
#      |████████████████████████████████| 7.8 MB 49.9 MB/s
# ...

# %%
import geopandas as gpd
import pandas as pd

# %%
#Loading the heat vulnalability data
heat = gpd.GeoDataFrame.from_file("https://opendata.arcgis.com/api/v3/datasets/ee1f9ce6aa6f41f08fcdfa5101f203d7_0/downloads/data?format=shp&spatialRefId=4326&where=1%3D1")

# %%
#Dispalying the data info
heat.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID_1  384 non-null    int64
#  1   GEOID10     384 non-null    object
#  2   NAME10      384 non-null    object
#  3   OBJECTID    376 non-null    float64
#  4   HSI_SCORE   376 non-null    float64
#  5   HEI_SCORE   374 non-null    float64
#  6   HVI_SCORE   374 non-null    float64
#  7   N_VERYHIGH  376 non-null    float64
#  8   Shape__Are  384 non-null    float64
#  9   Shape__Len  384 non-null    float64
#  10  geometry    384 non-null    geometry
# dtypes: float64(7), geometry(1), int64(1), object(2)
# memory usage: 33.1+ KB

# %%
#Check the data head
heat.head()
# Out:
#    OBJECTID_1      GEOID10 NAME10  OBJECTID  HSI_SCORE  HEI_SCORE  HVI_SCORE  \
# 0           1  42101019000    190      19.0   0.628858   0.130289   0.935255
# 1           2  42101019100    191      20.0   0.538256   2.208449   2.963969
# 2           3  42101019200    192      21.0   0.644698   1.705167   2.676547
# 3           4  42101019700    197      22.0  -0.807921   2.763526   3.156173
# 4           5  42101019800    198      23.0  -0.542459   2.549294   2.885302
#
#    N_VERYHIGH    Shape__Are   Shape__Len  \
# 0         0.0  1.350244e+06  5483.874734
# 1         1.0  2.491485e+06  7728.470750
# 2         1.0  1.120759e+06  5638.148182
# 3         1.0  7.688302e+05  3791.744189
# 4         1.0  9.234407e+05  4189.517838
#
#                                             geometry
# 0  POLYGON ((-75.09490 40.01049, -75.09497 40.010...
# 1  POLYGON ((-75.10715 40.01674, -75.10706 40.016...
# 2  POLYGON ((-75.10760 39.99967, -75.10815 39.999...
# ...

# %%
#Loading the tree distribution data
tree = gpd.GeoDataFrame.from_file("https://opendata.arcgis.com/api/v3/datasets/30ef36e9e880468fa74e2d5b18da4cfb_0/downloads/data?format=shp&spatialRefId=4326")

# %%
tree
# Out:
#         OBJECTID                                          TREE_NAME  TREE_DBH  \
# 0              1                             GINKGO BILOBA - GINKGO      36.0
# 1              2                     ACER PALMATUM - JAPANESE MAPLE       NaN
# 2              3                     ACER PALMATUM - JAPANESE MAPLE       8.0
# 3              4                     ACER PALMATUM - JAPANESE MAPLE      12.0
# 4              5               ACER PSEUDOPLATANUS - SYCAMORE MAPLE      17.0
# ...          ...                                                ...       ...
# 152448    152449                 CERCIS CANADENSIS - EASTERN REDBUD       5.0
# 152449    152450                    MALUS SPECIES - OTHER CRABAPPLE       3.0
# 152450    152451           SYRINGA RETICULATA - JAPANESE TREE LILAC       7.0
# 152451    152452  SYRINGIA RETICULATA - IVORY SILK JAPANESE TREE...       2.0
# 152452    152453                 ACER RUBRUM - RED SUNSET RED MAPLE       2.0
#
# ...

# %%
#Checking the tree data info
tree.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 152453 entries, 0 to 152452
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   OBJECTID   152453 non-null  int64
#  1   TREE_NAME  144676 non-null  object
#  2   TREE_DBH   152241 non-null  float64
#  3   YEAR       152453 non-null  object
#  4   LOC_X      152453 non-null  float64
#  5   LOC_Y      152453 non-null  float64
#  6   geometry   152453 non-null  geometry
# dtypes: float64(3), geometry(1), int64(1), object(2)
# memory usage: 8.1+ MB

# %%
tree.describe()
# Out:
#             OBJECTID       TREE_DBH          LOC_X          LOC_Y
# count  152453.000000  152241.000000  152453.000000  152453.000000
# mean    76227.000000      12.956631     -75.156120      39.993043
# std     44009.534632      14.024025       0.062479       0.051348
# min         1.000000       0.000000     -75.282717      39.874967
# 25%     38114.000000       4.000000     -75.197080      39.951005
# 50%     76227.000000      10.000000     -75.167736      39.982490
# 75%    114340.000000      20.000000     -75.131910      40.035098
# max    152453.000000    2028.000000     -74.958778      40.137451

# %%
heat.describe()
# Out:
#        OBJECTID_1    OBJECTID     HSI_SCORE   HEI_SCORE   HVI_SCORE  \
# count  384.000000  376.000000  3.760000e+02  374.000000  374.000000
# mean   192.500000  188.500000 -1.063830e-10    0.005262    0.013235
# std    110.995495  108.686092  1.414214e+00    1.730926    1.995821
# min      1.000000    1.000000 -4.382446e+00   -4.779247   -6.188905
# 25%     96.750000   94.750000 -8.375708e-01   -0.967293   -1.365208
# 50%    192.500000  188.500000 -1.498281e-01    0.042924    0.121218
# 75%    288.250000  282.250000  8.429508e-01    1.005599    1.415511
# max    384.000000  376.000000  6.520653e+00    6.103105    5.062507
#
#        N_VERYHIGH    Shape__Are    Shape__Len
# count  376.000000  3.840000e+02    384.000000
# mean     0.196809  1.639419e+06   5555.206372
# std      0.398116  2.541415e+06   4077.153549
# min      0.000000  1.797240e+05   1726.924865
# 25%      0.000000  6.795225e+05   3569.749650
# 50%      0.000000  1.024838e+06   4471.463073
# ...
